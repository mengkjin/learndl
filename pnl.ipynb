# %%
from src.factor.perf_api import main_test
main_test()
# Out:
# test :  ['DistributionCurve', 'DistributionQuantile', 'GroupCurve', 'GroupDecayRet', 'GroupDecayIR', 'GroupYearlyTop', 'ICCurve', 'ICDecay', 'ICIndustry', 'ICYearly', 'PnLCurve', 'StyleCorr']

# %%
from src.factor.data_util import DATAVENDOR
from src.factor.port_util import Benchmark

factor_val = DATAVENDOR.random_factor(20230701 , 20240331).to_dataframe()
benchmark  = Benchmark('csi300')

# %%
del factor_val['factor2']

# %%
from src.factor import perf_api as Calc
for calc_name in Calc.__all__:
    a = getattr(Calc , calc_name)()
    a.calc(factor_val , benchmark).plot()
