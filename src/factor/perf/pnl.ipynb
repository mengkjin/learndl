# %%
from src.factor.perf_api import main_test
main_test()
# Out:
# test :  ['DistributionCurve', 'DistributionQuantile', 'GroupCurve', 'GroupDecayRet', 'GroupDecayIR', 'GroupYearlyTop', 'ICCurve', 'ICDecay', 'ICIndustry', 'ICYearly', 'PnLCurve', 'StyleCorr']

# %%
from src.factor.perf_api import PnLCurve , DATAVENDOR , Benchmark

factor_val = DATAVENDOR.random_factor(20230701 , 20240331).to_dataframe()
benchmark  = Benchmark('csi500')

a = PnLCurve()
fig = a.calc(factor_val , benchmark).plot(True)

# %%
from src.factor.perf_api import PerfManager , DATAVENDOR , Benchmark

factor_val = DATAVENDOR.random_factor(20230701 , 20240331 , nfactor=1).to_dataframe()
benchmark  = Benchmark('csi1000')

pm = PerfManager(all=True)
pm.calc(factor_val , benchmark).plot(show=True)
# Out:
# PerfManager(perf_params={}, all=True, ic_curve=False, ic_decay=False, ic_indus=False, ic_yearly=False, pnl_curve=False, style_corr=False, group_curve=False, group_decay_ret=False, group_decay_ir=False, group_yearly=False, distr_curve=False, distr_qtile=False)

# %%
import mosek

# %%
from cvxopt import matrix
type(matrix)
# Out:
# type

# %%
pip install cvxopt cvxpy
# Out:
# Looking in indexes: https://pypi.tuna.tsinghua.edu.cn/simple
# ...
#      ---------------------------------------- 0.0/12.8 MB ? eta -:--:--
#      ---------------------------------------- 0.1/12.8 MB 3.2 MB/s eta 0:00:04
#      ---------------------------------------- 0.1/12.8 MB 1.3 MB/s eta 0:00:10
#      ---------------------------------------- 0.1/12.8 MB 1.3 MB/s eta 0:00:10
#       --------------------------------------- 0.2/12.8 MB 1.1 MB/s eta 0:00:12
#       --------------------------------------- 0.2/12.8 MB 1.1 MB/s eta 0:00:12
#       --------------------------------------- 0.3/12.8 MB 1.0 MB/s eta 0:00:13
#      - -------------------------------------- 0.3/12.8 MB 1.1 MB/s eta 0:00:12
#      - -------------------------------------- 0.3/12.8 MB 1.1 MB/s eta 0:00:12
#      - -------------------------------------- 0.3/12.8 MB 1.1 MB/s eta 0:00:12
#      - ------------------------------------- 0.4/12.8 MB 791.2 kB/s eta 0:00:16
# ...

# %%
xx
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 xx
#
# NameError: name 'xx' is not defined

# %%
benchmark.ports
# Out:
# <csi1000> : 37 ports
