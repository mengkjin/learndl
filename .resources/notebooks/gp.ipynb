# %%
from src.res.gp.util import GeneticProgramming

gp = GeneticProgramming.main()
gp
# Out:
# Project Verbosity Unchanged at 3
# Success : Job Directory is : "/Users/mengkjin/workspace/learndl/results/gp/bendi"
#   --> Caution : Start New Training in "/Users/mengkjin/workspace/learndl/results/gp/bendi"
# Using Device mps
# ********************************************* Genetic Programming Start at 2026-03-08 15:23:11 *********************************************
#   --> Directly load "/Users/mengkjin/workspace/learndl/data/Interim/GPPackage/test_package.pt"
#   --> 2 raw datas , 2 factors loaded!
# ********************************************** Iter 0 Gen 0 ~ 2 Start at 2026-03-08 15:23:12 ***********************************************
#   --> Evolve Generation 0 MaxIRres-8.49|MaxIRraw-8.49: 100%|██████████| 6/6 [00:13<00:00,  2.28s/it]
#   --> Success : Generation 0 Logbook Saved to "/Users/mengkjin/workspace/learndl/results/gp/bendi/logbook/iter0_gen0.pkl"
#   --> Evolve Generation 1 MaxIRres-13.14|MaxIRraw-13.14: 100%|██████████| 6/6 [00:07<00:00,  1.29s/it]
#   --> Success : Generation 1 Logbook Saved to "/Users/mengkjin/workspace/learndl/results/gp/bendi/logbook/iter0_gen1.pkl"
#   --> HallofFame(3) Contains 3 Promising Candidates with RankIR >= 1.00
#     --> Success : ts_btm_x(cp, 10, 2) : Hof__0 Pass Test [ts_btm_x(cp, 10, 2)] (Elite__1,IRraw-13.14|IRres-13.14|Corr+0.00)
#     --> Caution : ts_top_y_on_x(CP, cp, 20, 2) : Hof__1 Fail Test : Corr with Existing Factors Too High (+0.78)
#     --> Success : ts_top_x(cp, 40, 10) : Hof__2 Pass Test [ts_top_x(cp, 40, 10)] (Elite__2,IRraw-11.52|IRres-11.52|Corr+0.60)
#   --> Success : Generation 1 Logbook Saved to "/Users/mengkjin/workspace/learndl/results/gp/bendi/logbook/iter0_overall.pkl"
#   --> An EliteGroup of 2 has been Selected from HallofFame
# ************************************** Iter 0 Gen 0 ~ 2 Finish at 2026-03-08 15:23:37, Cost 25.7 Sec ***************************************
# ********************************************** Iter 0 Gen 0 ~ 2 Start at 2026-03-08 15:23:37 ***********************************************
#   --> Evolve Generation 0 MaxIRres-4.73|MaxIRraw-12.96: 100%|██████████| 6/6 [00:04<00:00,  1.43it/s]
#   --> Success : Generation 0 Logbook Saved to "/Users/mengkjin/workspace/learndl/results/gp/bendi/logbook/iter1_gen0.pkl"
#   --> Evolve Generation 1 MaxIRres-4.60|MaxIRraw-6.87: 100%|██████████| 6/6 [00:03<00:00,  1.68it/s]
#   --> Success : Generation 1 Logbook Saved to "/Users/mengkjin/workspace/learndl/results/gp/bendi/logbook/iter1_gen1.pkl"
#   --> HallofFame(3) Contains 3 Promising Candidates with RankIR >= 0.90
#     --> Success : power(TURN, 0.32) : Hof__0 Pass Test [power(TURN, 0.32)] (Elite__3,IRraw-7.25|IRres-3.59|Corr+0.00)
#     --> Success : ts_dif_y_on_x(TURN, CP, 10, 2) : Hof__1 Pass Test [ts_dif_y_on_x(TURN, CP, 10, 2)] (Elite__4,IRraw-6.82|IRres-4.60|Corr+0.27)
#     --> Caution : ts_corr(CP, TURN, 10) : Hof__2 Fail Test : EliteGroup is Full
#   --> Success : Generation 1 Logbook Saved to "/Users/mengkjin/workspace/learndl/results/gp/bendi/logbook/iter1_overall.pkl"
#   --> An EliteGroup of 2 has been Selected from HallofFame
# ************************************** Iter 0 Gen 0 ~ 2 Finish at 2026-03-08 15:23:48, Cost 10.8 Sec ***************************************
# Success : Historybook Saved to /Users/mengkjin/workspace/learndl/results/gp/bendi/logbook/historybook.pkl
# Timer Table:
#         category         name     total_time  avg_time  count
# 0            sigmoid       prima    0.0494     0.0494     1
# 1   ts_decay_pos_dif       prima    0.2744     0.2744     1
# 2               sign       prima    0.0032     0.0032     1
# 3           ts_delay       prima    0.0235     0.0235     1
# 4           ts_delta       prima    0.0069     0.0069     1
# 5        signedpower       prima    0.0351     0.0175     2
# 6             pctchg       prima    0.0139     0.0139     1
# 7       ts_lin_decay       prima    0.1020     0.1020     1
# 8            ts_corr       prima    0.2481     0.0827     3
# 9      ts_btm_y_on_x       prima    2.5431     1.2716     2
# 10     ts_top_y_on_x       prima    2.4683     0.6171     4
# 11     ts_dif_y_on_x       prima    4.8759     1.6253     3
# 12          ts_btm_x       prima    7.1769     1.7942     4
# 13          ts_top_x       prima    2.5900     1.2950     2
# 14          ts_dif_x       prima    5.3443     1.7814     3
# 15             stage        Data    0.4275     0.4275     1
# 16             stage   Iteration   36.5363    18.2681     2
# 17             stage     Setting    0.5375     0.2688     2
# 18             stage   Evolution   29.1894    14.5947     2
# 19             stage   Selection    6.8089     3.4045     2
# 20           process  Population    0.0027     0.0007     4
# 21           process     Compile    0.0030     0.0001    29
# 22           process    Evaluate   25.7558     0.8881    29
# 23           process     Process    2.5122     0.0866    29
# 24           process  Neutralize    0.0003     0.0000    29
# 25           process      Assess    7.1210     0.2967    24
# ************************************* Genetic Programming Finish at 2026-03-08 15:23:48, Cost 37.0 Sec *************************************
# Project Verbosity Unchanged at 3

# %%
from src.res.gp.util.generator import gpGenerator
gen = gpGenerator(None)
mf = gen.multi_elite_factor()
mf
# Out:
# Success : Load 2 Elites
# MultiFactorValue(value=Tensor((5335, 484),mps:0), weight=Tensor((1, 484, 2),mps:0), inputs=Tensor((5335, 484, 2),mps:0), names=['ts_zscore(CP, 15)', 'ts_corr(cp, turn, 10)'], secid=array(5335), date=20220104~20231229)
